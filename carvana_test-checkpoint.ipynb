# %% [markdown]
# ### Take home challenge: Carvana (02.2020)

# %% [markdown]
# Instructions: create a python script that pulls data from the attached five files to generate keyword bids based on the logic below
#
# Overall, the script should accomplish the following:
# o   Extract data from the five files
#
# o   Join the data as need
#
# o   Calculate KW level bids
#
# o   Generate a bid upload file
#
# o   Note: all data was fabricated for this exercise and does not represent Carvana’s performance or general business economics
#
# Definitions of terminology used are included at bottom of this email
# Bid upload file (per specs below)
# Python script used (instead of a Notebook) to generate the bid upload file
#
#
# Files included for your use:
#
# Inventory_Historical – contains the trailing 120 day average inventory by Mk/Mo/Yr
# Inventory_Current_Onsite – contains the current number of the vehicles on our site by make, model and year (e.g., 205 2013 Honda Accords, 150 2015 Toyota Camrys, etc)
# KW_Attributes – contains KW, KW ID, Ad Group, Campaign, Match Type, Quality Score, Est First Pos. Bid, Est Top of Page Bid
# KW_Performance_L120D – contains historical KW performance (impressions, clicks, cost, conversions) for prior 120 days by KW ID
# Make_Model_ARS – contains the historical average ARS for each make/model
#
#
# Bidding logic:
#
# Step 1: Calculate initial bid for each KW based on its historical performance
# a) If KW has >10 conversions
# Calculate KW bid based on KW’s historical performance
# New KW Bid = KW CVR * Mk/Mo ARS
# b) If KW has <11 conversions but ad group has >10 conversions
# Calculate KW bid based on its ad group’s historical performance
# New KW Bid = AG CVR * Mk/Mo ARS
# c) If AG has <11 conversions, but Mk/Mo/Yr has >10 conversions
# Calculate KW bid based on the Mk/Mo’s historical performance
# New KW bid = Mk/Mo/Yr CVR * Mk/Mo ARS
# d) If Mk/Mo/Yr has <11 conversions, but Mk/Mo has >10 conversions
# Calculate KW bid based on the Mk/Mo’s historical performance
# New KW bid = Mk/Mo CVR * Mk/Mo ARS
# e) If Mk/Mo has <11 conversions
# New KW bid = Est First Pos Bid
# Hint: aggregate KW data to level needed to get AG, Mk/Mo/Yr, Mk/Mo and Mkt level data
# Hint: several attributes (e.g., Mkt, Mk/Mo, etc) will need to be extracted from CMPN and AG names
#
#
# Step 2: Adjust calculated bid based on the following considerations:
# a) Adjust bid based on current onsite inventory
# If current Mk/Mo/Yr inv < hist Mk/Mo/Yr inv
# Reduce KW bid by % equal to half the % diff between current and historical inv
# E.g., if hist avg is 20 and current inv is 15, reduce bid by 12.5% (i.e., half of 25%)
# b) Adjust bid based on Mkt CVR only for KWs whose bids were calculated based on Mk/Mo/Yr or Mk/Mo CVR (i.e., not based on KW or AG CVR)
# Increase/decrease KW bid by the half the % above or below overall site CVR the market CVR is relative to overall site average
# i.e., if overall CVR for the entire site is 1.0% and DAL overall CVR is 1.07%, increase bids for KWs in DAL by 3.5%
# c) Cap bids at reasonable levels, based on their quality score
# KWs with QS>7 cannot be higher than Est First Pos Bid
# KWs with QS<8 and QS>5 cannot be higher than average of Est Top of Page Bid and Est First Pos Bid
# KWs with QS<6 cannot be higher than (Est Top of Page Bid *0.9) + (Est First Pos Bid *0.1)
# No bids can be higher than $12
# d) Cap bids of broad match KWs
# Ensure that no bid for a broad match KW is greater than any bid for an exact match KW within the same ad group
# E.g., if bids for exact match KWs within the same ad group are $1.50, $1.75 and $1.60, then if a broad match KW with a calculated of bid of $2.00 should have its bid reduced to $1.50
#
#
# Bid upload file:
#
# Format: CSV
# Columns to include:
# o   Keyword ID
#
# o   Bid
#
#
#
# Definitions:
#
# KW = keyword
# AG = ad group
# CMPN = campaign
# o   Campaigns target geographical areas where users are located (e.g., a campaign could target all people physically located in Dallas)
#
# o   CMPNs contain multiple AGs; AGs contain multiple KWs (learn more here)
#
# QS = quality score = value google assigns to each KW based (learn more here)
# Impressions = # of times a KW’s ad was seen on in google search results
# Clicks = # of times the KW’s ads were clicked (i.e., # of times people clicked through to carvana.com)
# Conversions = # of car sales generated from the clicks
# CTR = click through rate = clicks / impressions
# CVR = conversion rate = conversions / clicks
# ARS = average revenue per sale = amount of money Carvana makes per car sold
# o   This is specific to each make and model, but not by year
#
# Est First Pos. Bid = Google’s estimate for the bid required to show up in first position (see below)
# Est Top of Page Bid = Google’s estimate for the bid required to show up at the top of the page (i.e., 4th position)
# Mkt = Market = the geography the campaign is targeting
# o   ATL = Atlanta
#
# o   DAL = Dallas
#
# o   NYC = New York City
#
# o   CHI = Chicago
#
# o   SFO = San Francisco
#
# Mk/Mo/Yr = combination of make, model and year

# %%
import pandas as pd
import numpy as np

# %%
# Combine 5 data files.
# combine 'KW_Attributes.xlsx' and 'KW_Performance_L120D.XLSX ' using "KW ID"
kw_attributes_df = pd.read_excel('D:\\111. Take home challenge\\Carvana-27.02.2020\\KW_Attributes.xlsx')
kw_attributes_df.shape
# Out:
# (3450, 8)

# %%
kw_attributes_df.head()
# Out:
#           Campaign                             Ad group  \
# 0  SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12
# 1  SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_14
# 2  SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_15
# 3  SRCH-I-ATL-TOTL      SRCH-I-ATL-MK_Kia-MO_Soul-YR_15
# 4  SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_13
#
#                            Keyword      KW ID Match type  Quality score  \
# 0             +2012 +toyota +camry  371462857      Broad             10
# 1  +2014 +toyota +camry +for +sale  540282177      Broad             10
# 2  +2015 +toyota +camry +for +sale  518188218      Broad              9
# 3                 +2015 +kia +soul  698853859      Broad             10
# 4             +toyota +camry +2013  534068489      Broad              7
#
#    Est First Pos. Bid  Est Top of Page Bid
# 0            9.979746             8.316455
# 1           11.620050             9.683375
# 2            8.635562             7.196302
# 3           10.979037             9.149198
# 4           10.474498             5.844252

# %%
# Read kw_performance.xlxs file
kw_performance_df = pd.read_excel('D:\\111. Take home challenge\\Carvana-27.02.2020\\KW_Performance_L120D.XLSX')
kw_performance_df.shape
# Out:
# (3450, 5)

# %%
kw_performance_df.head()
# Out:
#        KW ID  Impressions  Clicks         Cost  Conversions
# 0  371462857        10650    1540  5798.319872           22
# 1  540282177        44350     560  1383.842480           17
# 2  518188218        38840     870  2930.030504            9
# 3  698853859        40470     340   676.402686            8
# 4  534068489        32940     520  2872.377114           43

# %%
kw_att_perf_df = kw_attributes_df.merge(kw_performance_df,on=['KW ID'])
kw_att_perf_df.head()
# Out:
#           Campaign                             Ad group  \
# 0  SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12
# 1  SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_14
# 2  SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_15
# 3  SRCH-I-ATL-TOTL      SRCH-I-ATL-MK_Kia-MO_Soul-YR_15
# 4  SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_13
#
#                            Keyword      KW ID Match type  Quality score  \
# 0             +2012 +toyota +camry  371462857      Broad             10
# 1  +2014 +toyota +camry +for +sale  540282177      Broad             10
# 2  +2015 +toyota +camry +for +sale  518188218      Broad              9
# 3                 +2015 +kia +soul  698853859      Broad             10
# 4             +toyota +camry +2013  534068489      Broad              7
#
#    Est First Pos. Bid  Est Top of Page Bid  Impressions  Clicks         Cost  \
# 0            9.979746             8.316455        10650    1540  5798.319872
# 1           11.620050             9.683375        44350     560  1383.842480
# 2            8.635562             7.196302        38840     870  2930.030504
# 3           10.979037             9.149198        40470     340   676.402686
# 4           10.474498             5.844252        32940     520  2872.377114
#
#    Conversions
# 0           22
# 1           17
# 2            9
# 3            8
# 4           43

# %%
kw_att_perf_df.shape
# Out:
# (3450, 12)

# %%
# Create & append new column 'CVR' - conversion rate. to the df.
kw_att_perf_df['CVR'] = kw_att_perf_df['Conversions']/kw_att_perf_df['Clicks']
kw_att_perf_df['CVR']
# Out:
# 0       0.014286
# 1       0.030357
# 2       0.010345
# 3       0.023529
# 4       0.082692
# 5       0.024000
# 6       0.003000
# 7       0.037500
# 8       0.008772
# 9       0.043333
# 10      0.012766
# 11      0.003774
# 12      0.008197
# 13      0.038462
# 14      0.005495
# 15      0.008333
# 16      0.060345
# 17      0.005128
# 18      0.003371
# 19      0.014000
# 20      0.026119
# 21      0.085366
# 22      0.022152
# 23      0.052239
# 24      0.018182
# 25      0.016418
# 26      0.031325
# 27      0.004301
# 28      0.004878
# 29      0.015758
#           ...
# 3420    0.000000
# 3421    0.000000
# 3422    0.000000
# 3423    0.000000
# 3424    0.000000
# 3425    0.000000
# 3426    0.000000
# 3427    0.000000
# 3428    0.000000
# 3429    0.000000
# 3430    0.000000
# 3431    0.000000
# 3432    0.000000
# 3433    0.000000
# 3434    0.000000
# 3435    0.000000
# 3436    0.000000
# 3437    0.000000
# 3438    0.000000
# 3439    0.000000
# 3440    0.000000
# 3441    0.000000
# 3442    0.000000
# 3443    0.000000
# 3444    0.000000
# 3445    0.000000
# 3446    0.000000
# 3447    0.000000
# 3448    0.000000
# 3449    0.000000
# Name: CVR, Length: 3450, dtype: float64

# %%
kw_att_perf_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3450 entries, 0 to 3449
# Data columns (total 13 columns):
# Campaign               3450 non-null object
# Ad group               3450 non-null object
# Keyword                3450 non-null object
# KW ID                  3450 non-null int64
# Match type             3450 non-null object
# Quality score          3450 non-null int64
# Est First Pos. Bid     3450 non-null float64
# Est Top of Page Bid    3450 non-null float64
# Impressions            3450 non-null int64
# Clicks                 3450 non-null int64
# Cost                   3450 non-null float64
# Conversions            3450 non-null int64
# CVR                    3448 non-null float64
# dtypes: float64(4), int64(5), object(4)
# memory usage: 537.3+ KB

# %% [markdown]
# ## Step 1: Calculate initial bid for each KW based on its historical performance

# %% [markdown]
# ### 1a) If KW has >10 conversions
# * Calculate KW bid based on KW’s historical performance
#
# * New KW Bid = KW CVR * Mk/Mo ARS
#
# Note:
#
# KW CVR = 'Conversions'
#
# Mk/Mo ASR = ASR is in 'Make_model_ASR.xlsx' file

# %%
inventory_onsite_df = pd.read_excel('D:\\111. Take home challenge\\Carvana-27.02.2020\\Inventory_Current_Onsite.xlsx')
inventory_onsite_df.shape
# Out:
# (115, 4)

# %%
inventory_onsite_df.head()
# Out:
#       Make    Model  Year  CurrentOnsiteInventory
# 0   Toyota    Camry  2013                     176
# 1      Kia     Soul  2013                      92
# 2    Honda    Civic  2013                     113
# 3   Toyota  Corolla  2013                      72
# 4  Hyundai  Elantra  2013                      77

# %%
inventory_hist_df = pd.read_excel('D:\\111. Take home challenge\\Carvana-27.02.2020\\Inventory_Historical.xlsx')
inventory_hist_df.shape
# Out:
# (115, 4)

# %%
inventory_hist_df.head()
# Out:
#       Make    Model  Year  HistAvgInv
# 0   Toyota    Camry  2013         143
# 1      Kia     Soul  2013         140
# 2    Honda    Civic  2013         124
# 3   Toyota  Corolla  2013         120
# 4  Hyundai  Elantra  2013         114

# %%
inventory_df = inventory_onsite_df.merge(inventory_hist_df, on=['Make','Model','Year'])

# %%
inventory_df.head()
# Out:
#       Make    Model  Year  CurrentOnsiteInventory  HistAvgInv
# 0   Toyota    Camry  2013                     176         143
# 1      Kia     Soul  2013                      92         140
# 2    Honda    Civic  2013                     113         124
# 3   Toyota  Corolla  2013                      72         120
# 4  Hyundai  Elantra  2013                      77         114

# %%
ars_df = pd.read_excel('D:\\111. Take home challenge\\Carvana-27.02.2020\\Make_Model_ASR.XLSX')
ars_df.shape
# Out:
# (23, 4)

# %%
inventory_ars_df = inventory_df.merge(ars_df, on=['Make','Model'])

# %%
inventory_ars_df.shape
# Out:
# (115, 7)

# %%
inventory_ars_df.head()
# Out:
#      Make  Model  Year  CurrentOnsiteInventory  HistAvgInv    Make Model  \
# 0  Toyota  Camry  2013                     176         143  Toyota Camry
# 1  Toyota  Camry  2012                      30          57  Toyota Camry
# 2  Toyota  Camry  2014                      52          43  Toyota Camry
# 3  Toyota  Camry  2015                      13          23  Toyota Camry
# 4  Toyota  Camry  2011                      14          20  Toyota Camry
#
#           ASR
# 0  930.517547
# 1  930.517547
# 2  930.517547
# 3  930.517547
# 4  930.517547

# %%
# Extract'MK_MO' or 'MK_MO_YR'
import re

def extract_mk_mo_yr(adgroup):
    m = re.findall(r'MK_(\w+)-MO_(\w+)-YR_(\d{2})',adgroup)
    mk = m[0][0]
    mo = m[0][1]
    yr = '20'+m[0][2]
    mk_mo = mk + ' ' + mo
    mk_mo_yr = mk + ' ' + mo + ' ' + yr
    
    print(mk)
    print(mo)
    print(yr)
    return mk_mo, mk_mo_yr
    
MK_MO, MK_MO_YR = extract_mk_mo_yr('SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12')
print('mk_mo:', MK_MO)
print('mk_mo_yr:',MK_MO_YR)
# Out:
# Toyota
# Camry
# 2012
# mk_mo: Toyota Camry
# mk_mo_yr: Toyota Camry 2012

# %%
# Create new columns MK_MO, MK_MO_YR and append it to the  'kw_att_perf_df'
kw_att_perf_df['Make'] = kw_att_perf_df['Ad group'].str.extract(r'MK_(\w+)-',expand=True)

# %%
kw_att_perf_df['Make'].head()
# Out:
# 0    Toyota
# 1    Toyota
# 2    Toyota
# 3       Kia
# 4    Toyota
# Name: Make, dtype: object

# %%
# Extract new columns df['Mo'] and append it to df.
kw_att_perf_df['Model'] = kw_att_perf_df['Ad group'].str.extract(r'MO_(\w+)-',expand=True)
kw_att_perf_df['Model'].head()
# Out:
# 0    Camry
# 1    Camry
# 2    Camry
# 3     Soul
# 4    Camry
# Name: Model, dtype: object

# %%
# Extract new columns df['Yr'] and append it to df.
kw_att_perf_df['Year'] = '20' + kw_att_perf_df['Ad group'].str.extract('YR_(\d{2})',expand=True)
kw_att_perf_df['Year'].head()
# Out:
# 0    2012
# 1    2014
# 2    2015
# 3    2015
# 4    2013
# Name: Year, dtype: object

# %%
# Create a new column call 'Mk/Mo' 
kw_att_perf_df['Mk/Mo'] = kw_att_perf_df['Make'] + ' ' + kw_att_perf_df['Model']

# %%
# Create a new column call 'Mk/Mo/Yr' 
kw_att_perf_df['Mk/Mo/Yr'] = kw_att_perf_df['Make'] + ' ' + kw_att_perf_df['Model'] + ' ' + kw_att_perf_df['Year']

# %%
# Merge df on ARS file
kw_att_perf_df.merge(inventory_ars_df, how='left',on = ['Make','Model'])
# Out:
#               Campaign                             Ad group  \
# 0      SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12
# 1      SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12
# 2      SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12
# 3      SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12
# 4      SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12
# 5      SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_14
# 6      SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_14
# 7      SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_14
# 8      SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_14
# 9      SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_14
# 10     SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_15
# 11     SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_15
# 12     SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_15
# 13     SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_15
# 14     SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_15
# 15     SRCH-I-ATL-TOTL      SRCH-I-ATL-MK_Kia-MO_Soul-YR_15
# 16     SRCH-I-ATL-TOTL      SRCH-I-ATL-MK_Kia-MO_Soul-YR_15
# 17     SRCH-I-ATL-TOTL      SRCH-I-ATL-MK_Kia-MO_Soul-YR_15
# 18     SRCH-I-ATL-TOTL      SRCH-I-ATL-MK_Kia-MO_Soul-YR_15
# 19     SRCH-I-ATL-TOTL      SRCH-I-ATL-MK_Kia-MO_Soul-YR_15
# 20     SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_13
# 21     SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_13
# 22     SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_13
# 23     SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_13
# 24     SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_13
# 25     SRCH-I-ATL-TOTL   SRCH-I-ATL-MK_Honda-MO_Civic-YR_15
# 26     SRCH-I-ATL-TOTL   SRCH-I-ATL-MK_Honda-MO_Civic-YR_15
# 27     SRCH-I-ATL-TOTL   SRCH-I-ATL-MK_Honda-MO_Civic-YR_15
# 28     SRCH-I-ATL-TOTL   SRCH-I-ATL-MK_Honda-MO_Civic-YR_15
# 29     SRCH-I-ATL-TOTL   SRCH-I-ATL-MK_Honda-MO_Civic-YR_15
# ...                ...                                  ...
# 17220  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_14
# 17221  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_14
# 17222  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_14
# 17223  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_14
# 17224  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_14
# 17225  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17226  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17227  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17228  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17229  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17230  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17231  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17232  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17233  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17234  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17235  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17236  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17237  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17238  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17239  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17240  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17241  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17242  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17243  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17244  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17245  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17246  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17247  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 17248  SRCH-I-SFO-TOTL  SRCH-I-SFO-MK_Toyota-MO_Prius-YR_15
# 6       2012                     30         57  Toyota Camry   930.517547
# 7       2014                     52         43  Toyota Camry   930.517547
# 8       2015                     13         23  Toyota Camry   930.517547
# 9       2011                     14         20  Toyota Camry   930.517547
# 10      2013                    176        143  Toyota Camry   930.517547
# 11      2012                     30         57  Toyota Camry   930.517547
# 12      2014                     52         43  Toyota Camry   930.517547
# 13      2015                     13         23  Toyota Camry   930.517547
# 14      2011                     14         20  Toyota Camry   930.517547
# 15      2013                     92        140      Kia Soul   975.778126
# 16      2012                     56         56      Kia Soul   975.778126
# 17      2014                     42         42      Kia Soul   975.778126
# 18      2015                     12         22      Kia Soul   975.778126
# 19      2011                     11         20      Kia Soul   975.778126
# 20      2013                    176        143  Toyota Camry   930.517547
# 21      2012                     30         57  Toyota Camry   930.517547
# 22      2014                     52         43  Toyota Camry   930.517547
# 23      2015                     13         23  Toyota Camry   930.517547
# 24      2011                     14         20  Toyota Camry   930.517547
# 25      2013                    113        124   Honda Civic  1120.123183
# 26      2012                     70         50   Honda Civic  1120.123183
# 27      2014                     42         37   Honda Civic  1120.123183
# 28      2015                     23         20   Honda Civic  1120.123183
# 29      2011                     20         17   Honda Civic  1120.123183
# ...      ...                    ...        ...           ...          ...
# 17220   2013                    137        101  Toyota Prius  1088.587793
# 17221   2012                     24         40  Toyota Prius  1088.587793
# 17222   2014                     37         30  Toyota Prius  1088.587793
# 17223   2015                     22         16  Toyota Prius  1088.587793
# 17224   2011                     12         14  Toyota Prius  1088.587793
# 17225   2013                    137        101  Toyota Prius  1088.587793
# 17226   2012                     24         40  Toyota Prius  1088.587793
# 17227   2014                     37         30  Toyota Prius  1088.587793
# 17228   2015                     22         16  Toyota Prius  1088.587793
# 17229   2011                     12         14  Toyota Prius  1088.587793
# 17230   2013                    137        101  Toyota Prius  1088.587793
# 17231   2012                     24         40  Toyota Prius  1088.587793
# 17232   2014                     37         30  Toyota Prius  1088.587793
# 17233   2015                     22         16  Toyota Prius  1088.587793
# 17234   2011                     12         14  Toyota Prius  1088.587793
# 17235   2013                    137        101  Toyota Prius  1088.587793
# 17236   2012                     24         40  Toyota Prius  1088.587793
# 17237   2014                     37         30  Toyota Prius  1088.587793
# 17238   2015                     22         16  Toyota Prius  1088.587793
# 17239   2011                     12         14  Toyota Prius  1088.587793
# 17240   2013                    137        101  Toyota Prius  1088.587793
# 17241   2012                     24         40  Toyota Prius  1088.587793
# 17242   2014                     37         30  Toyota Prius  1088.587793
# 17243   2015                     22         16  Toyota Prius  1088.587793
# 17244   2011                     12         14  Toyota Prius  1088.587793
# 17245   2013                    137        101  Toyota Prius  1088.587793
# 17246   2012                     24         40  Toyota Prius  1088.587793
# 17247   2014                     37         30  Toyota Prius  1088.587793
# 17248   2015                     22         16  Toyota Prius  1088.587793
# 17249   2011                     12         14  Toyota Prius  1088.587793
#
# [17250 rows x 26 columns]

# %%
kw_att_perf_df.columns
# Out:
# Index(['Campaign', 'Ad group', 'Keyword', 'KW ID', 'Match type',
#        'Quality score', 'Est First Pos. Bid', 'Est Top of Page Bid',
#        'Impressions', 'Clicks', 'Cost', 'Conversions', 'CVR', 'Mk', 'Mo', 'Yr',
#        'Make', 'Model', 'Year', 'Mk/Mo', 'Mk/Mo/Yr'],
#       dtype='object')

# %%
kw_att_perf_df.shape
# Out:
# (3450, 21)

# %% [markdown]
# ### Question 1a:
# If KW has >10 conversions
#
# •Calculate KW bid based on KW’s historical performance
#
#
# •New KW Bid = KW CVR * Mk/Mo ARS
#
# Note:
# CVR = conversion rate = conversions / clicks
#
# ARS = average revenue per sale = amount of money Carvana makes per car sold

# %%
# Answer 1a.
# new_kw_bid = kw_att_perf_df.loc[kw_att_perf_df['Conversions'] > 10,'Conversion'] * kw_att_perf_df['ARS']
# kw_att_perf_df.loc[kw_att_perf_df['Conversions'] > 10]
kw_att_perf_df.columns
# Out:
# Index(['Campaign', 'Ad group', 'Keyword', 'KW ID', 'Match type',
#        'Quality score', 'Est First Pos. Bid', 'Est Top of Page Bid',
#        'Impressions', 'Clicks', 'Cost', 'Conversions', 'CVR', 'Mk', 'Mo', 'Yr',
#        'Make', 'Model', 'Year', 'Mk/Mo', 'Mk/Mo/Yr'],
#       dtype='object')

# %%
new_kw_big = np.where(kw_att_perf_df['Conversions'] > 10, kw_att_perf_df['CVR']*kw_att_perf_df['ASR'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\samsung\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ASR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-3b4c3d5e5b5e> in <module>()
# ----> 1 new_kw_big = np.where(kw_att_perf_df['Conversions'] > 10, kw_att_perf_df['CVR']*kw_att_perf_df['ASR'])
#
# C:\Users\samsung\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# C:\Users\samsung\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# C:\Users\samsung\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# C:\Users\samsung\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\Users\samsung\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ASR'

# %%
for i, row in kw_att_perf_df[:10].iterrows():
    # if conversions > 10:
    if kw_att_perf_df.loc[i,'Conversions'] > 10:
        print(row)
        keyword = kw_att_perf_df.loc[i,'Keyword']
        kws = keyword.split()
        make = kws[1]
        
        #Calculate CVR (Conversion rate)
        # CVR = conversions / clicks
        print('Conversions:',kw_att_perf_df.loc[i,'Conversions'])
        print('Clicks:',kw_att_perf_df.loc[i,'Clicks'])
        CVR = kw_att_perf_df.loc[i,'Conversions'] / kw_att_perf_df.loc[i,'Clicks']
        print('CVR:', CVR)
        
        #new_kw_bid = kw_att_perf_df.loc[i,'Conversions'] * ars
        print('\n')
# Out:
# Campaign                                   SRCH-I-ATL-TOTL
# Ad group               SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12
# Keyword                               +2012 +toyota +camry
# KW ID                                            371462857
# Match type                                           Broad
# Quality score                                           10
# Est First Pos. Bid                                 9.97975
# Est Top of Page Bid                                8.31645
# Impressions                                          10650
# Clicks                                                1540
# Cost                                               5798.32
# Conversions                                             22
# Name: 0, dtype: object
# Conversions: 22
# Clicks: 1540
# CVR: 0.0142857142857
#
#
# Campaign                                   SRCH-I-ATL-TOTL
# Ad group               SRCH-I-ATL-MK_Toyota-MO_Camry-YR_14
# Keyword                    +2014 +toyota +camry +for +sale
# KW ID                                            540282177
# Match type                                           Broad
# Quality score                                           10
# Est First Pos. Bid                                 11.6201
# Est Top of Page Bid                                9.68338
# Impressions                                          44350
# Clicks                                                 560
# Cost                                               1383.84
# Conversions                                             17
# Name: 1, dtype: object
# Conversions: 17
# Clicks: 560
# CVR: 0.0303571428571
#
#
# Campaign                                   SRCH-I-ATL-TOTL
# Ad group               SRCH-I-ATL-MK_Toyota-MO_Camry-YR_13
# Keyword                               +toyota +camry +2013
# KW ID                                            534068489
# Match type                                           Broad
# Quality score                                            7
# Est First Pos. Bid                                 10.4745
# Est Top of Page Bid                                5.84425
# Impressions                                          32940
# Clicks                                                 520
# Cost                                               2872.38
# Conversions                                             43
# Name: 4, dtype: object
# Conversions: 43
# Clicks: 520
# CVR: 0.0826923076923
#
#
# Campaign                                   SRCH-I-DAL-TOTL
# Ad group               SRCH-I-DAL-MK_Toyota-MO_Camry-YR_13
# Keyword                    +2013 +toyota +camry +for +sale
# KW ID                                            486105700
# Match type                                           Broad
# Quality score                                           10
# Est First Pos. Bid                                 11.8612
# Est Top of Page Bid                                 4.6057
# Impressions                                          23800
# Clicks                                                 900
# Cost                                               1937.82
# Conversions                                             39
# Name: 9, dtype: object
# Conversions: 39
# Clicks: 900
# CVR: 0.0433333333333

# %%
import numpy as np
import pandas as pd
import re

# Read 5 data file.
kw_attributes_df = pd.read_excel('D:\\111. Take home challenge\\Carvana-27.02.2020\\KW_Attributes.xlsx')
kw_performance_df = pd.read_excel('D:\\111. Take home challenge\\Carvana-27.02.2020\\KW_Performance_L120D.XLSX')
inventory_hist_df = pd.read_excel('D:\\111. Take home challenge\\Carvana-27.02.2020\\Inventory_Historical.xlsx')
inventory_curr_df = pd.read_excel('D:\\111. Take home challenge\\Carvana-27.02.2020\\Inventory_Current_Onsite.xlsx')
make_model_ars_df = pd.read_excel('D:\\111. Take home challenge\\Carvana-27.02.2020\\Make_Model_ASR.xlsx')

# Merge file 'attributes' and 'performance'.
df = kw_attributes_df.merge(kw_performance_df,on=['KW ID']) # merge kw files.

# Extract 'Make', 'Model' from AdGroup.
# Create new columns MK_MO, MK_MO_YR and append it to the  'kw_att_perf_df'
df['Make'] = df['Ad group'].str.extract(r'MK_(\w+)-', expand=True)
df['Model'] = kw_att_perf_df['Ad group'].str.extract(r'MO_(\w+)-', expand=True)
df['Year'] = '20' + kw_att_perf_df['Ad group'].str.extract('YR_(\d{2})', expand=True)

df['Mk/Mo'] = kw_att_perf_df['Make'] + ' ' + kw_att_perf_df['Model']
df['Mk/Mo/Yr'] = kw_att_perf_df['Make'] + ' ' + kw_att_perf_df['Model'] + ' ' + kw_att_perf_df['Year']

# Merge inventory_hist_df, inventory_curr_df, make_model_ars_df.
df = df.merge(inventory_hist_df, on=['Make', 'Model'])
df = df.merge(inventory_curr_df, on=['Make', 'Model'])
df = df.merge(make_model_ars_df, on=['Make', 'Model'])


# Create new column 'CVR'.
df['CVR'] = df['Conversions']/df['Clicks']

# %%
df.columns
# Out:
# Index(['Campaign', 'Ad group', 'Keyword', 'KW ID', 'Match type',
#        'Quality score', 'Est First Pos. Bid', 'Est Top of Page Bid',
#        'Impressions', 'Clicks', 'Cost', 'Conversions', 'Make', 'Model',
#        'Year_x', 'Mk/Mo', 'Mk/Mo/Yr', 'Year_y', 'HistAvgInv', 'Year',
#        'CurrentOnsiteInventory', 'Make Model', 'ASR', 'CVR'],
#       dtype='object')

# %%
df.head()
# Out:
#           Campaign                             Ad group               Keyword  \
# 0  SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12  +2012 +toyota +camry
# 1  SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12  +2012 +toyota +camry
# 2  SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12  +2012 +toyota +camry
# 3  SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12  +2012 +toyota +camry
# 4  SRCH-I-ATL-TOTL  SRCH-I-ATL-MK_Toyota-MO_Camry-YR_12  +2012 +toyota +camry
#
#        KW ID Match type  Quality score  Est First Pos. Bid  \
# 0  371462857      Broad             10            9.979746
# 1  371462857      Broad             10            9.979746
# 2  371462857      Broad             10            9.979746
# 3  371462857      Broad             10            9.979746
# 4  371462857      Broad             10            9.979746
#
#    Est Top of Page Bid  Impressions  Clicks    ...     Year_x         Mk/Mo  \
# 0             8.316455        10650    1540    ...       2012  Toyota Camry
# 1             8.316455        10650    1540    ...       2012  Toyota Camry
# 2             8.316455        10650    1540    ...       2012  Toyota Camry
# 3             8.316455        10650    1540    ...       2012  Toyota Camry
# 4             8.316455        10650    1540    ...       2012  Toyota Camry
#
#             Mk/Mo/Yr Year_y HistAvgInv  Year CurrentOnsiteInventory  \
# 0  Toyota Camry 2012   2013        143  2013                    176
# 1  Toyota Camry 2012   2013        143  2012                     30
# 2  Toyota Camry 2012   2013        143  2014                     52
# 3  Toyota Camry 2012   2013        143  2015                     13
# 4  Toyota Camry 2012   2013        143  2011                     14
#
#      Make Model         ASR       CVR
# 0  Toyota Camry  930.517547  0.014286
# 1  Toyota Camry  930.517547  0.014286
# 2  Toyota Camry  930.517547  0.014286
# 3  Toyota Camry  930.517547  0.014286
# 4  Toyota Camry  930.517547  0.014286
#
# [5 rows x 24 columns]

# %%
# Calculate new bid.
new_kw_big = np.where(df['Conversions'] > 10, df['CVR']*df['ASR'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-1fdb3d9b3fb8> in <module>()
#       1 # Calculate new bid.
# ----> 2 new_kw_big = np.where(df['Conversions'] > 10, df['CVR']*df['ASR'])
#
# ValueError: either both or neither of x and y should be given

# %%
new_bid = df.where(df['Conversions'] > 10, df['CVR']*df['ASR'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-ad2f7abf629d> in <module>()
# ----> 1 new_bid = df.where(df['CVR']*df['ASR'],df['Conversions'] > 10)
#
# C:\Users\samsung\Anaconda3\lib\site-packages\pandas\core\generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast, raise_on_error)
#    7770         other = com._apply_if_callable(other, self)
#    7771         return self._where(cond, other, inplace, axis, level,
# -> 7772                            errors=errors, try_cast=try_cast)
#    7773
#    7774     @Appender(_shared_docs['where'] % dict(_shared_doc_kwargs, cond="False",
#
# C:\Users\samsung\Anaconda3\lib\site-packages\pandas\core\generic.py in _where(self, cond, other, inplace, axis, level, errors, try_cast)
#    7531             for dt in cond.dtypes:
#    7532                 if not is_bool_dtype(dt):
# -> 7533                     raise ValueError(msg.format(dtype=dt))
#    7534
#    7535         cond = -cond if inplace else cond
#
# ValueError: Boolean array expected for the condition, not object

# %%
# create a sub_df
sub_df = df.loc[df['Conversions'] > 10,['KW ID','CVR','ASR']]

# %%
# Question 1a. Calculate new KW bid.
sub_df['KW_BID'] = sub_df['CVR'] * sub_df['ASR']

