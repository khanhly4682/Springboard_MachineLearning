# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import KFold
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
#from sklearn.metrics import plot_roc_curve
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier
from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
# Read training data
adult_train= pd.read_csv("D:\\ASU Application\\1-Data Visualization\\Project\\data\\adult.data", header=None)
adult_test = pd.read_csv("D:\\ASU Application\\1-Data Visualization\\Project\\data\\adult.test", header=None)
columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','salary']
adult_train.columns=columns
adult_test.columns =columns
adult_train.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
adult_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# salary            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adult_train.salary.value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: salary, dtype: int64

# %% [markdown]
# ### Missing data

# %%
adult_train.workclass.value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64

# %%
adult_train['occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
a = adult_train['occupation'] =="?"
a
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: occupation, Length: 32561, dtype: bool

# %%
a.value_counts()
# Out:
# False    32561
# Name: occupation, dtype: int64

# %% [markdown]
# ### Cleaning data

# %%
cleaned_train_df = pd.read_csv("D:\\ASU Application\\1-Data Visualization\\Project\\data\\adult_data_cleaned.csv")
cleaned_test_df = pd.read_csv("D:\\ASU Application\\1-Data Visualization\\Project\\data\\adult_test_cleaned.csv")
cleaned_train_df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States       0
# ...

# %%
cleaned_train_df['salary'].value_counts()
# Out:
# 0    22654
# 1     7508
# Name: salary, dtype: int64

# %%
cleaned_test_df['salary'].value_counts()
# Out:
# 0    11360
# 1     3700
# Name: salary, dtype: int64

# %%
test_df.head()
# Out:
#    age   workclass  fnlwgt      education  education-num       marital-status  \
# 0   25     Private  226802           11th              7        Never-married
# 1   38     Private   89814        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov  336951     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private  160323   Some-college             10   Married-civ-spouse
# 4   34     Private  198693           10th              6        Never-married
#
#            occupation    relationship    race    sex  capital-gain  \
# 0   Machine-op-inspct       Own-child   Black   Male             0
# 1     Farming-fishing         Husband   White   Male             0
# 2     Protective-serv         Husband   White   Male             0
# 3   Machine-op-inspct         Husband   Black   Male          7688
# 4       Other-service   Not-in-family   White   Male             0
#
#    capital-loss  hours-per-week  native-country
# ...

# %%
test_target_df.value_counts()
# Out:
# 0    11360
# 1     3700
# Name: salary, dtype: int64

# %% [markdown]
# ### Encoding

# %%
# Encoding categorical data
X = pd.get_dummies(train_df)
y = train_target_df

#X_test = pd.get_dummies(test_df)
#y_test = test_target_df

# %% [markdown]
# ### Prepare the data
#
# Since the data set is unbalanced, we will use undersampling techniques

# %%
#Seperate the targe variable in the dataset.
train_df = cleaned_train_df.iloc[:,:-1]
test_df  = cleaned_test_df.iloc[:,:-1]

train_target_df = cleaned_train_df.iloc[:,-1]
test_target_df = cleaned_test_df.iloc[:,-1]

# Baseline model
def log_regression(X,y):
    # Create training, test set.
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

    # Create Logistic Regression model.
    lr = LogisticRegression()

    # Fit the model
    lr.fit(X_train,y_train)

    # Make predict the test set
    y_predict_test = lr.predict(X_test)
    print("\n")
    print("[Test] Accuracy score (y_predict_test, ytestlr):",accuracy_score(y_predict_test, y_test))

    # the training score
    y_predict_training = lr.predict(X_train)
    print("\n")
    print("[Training] Accuracy score: (ylr, y_predict_training)",accuracy_score(y_train, y_predict_training))
    print(classification_report(y_test,y_predict_test ))


# Run logistic regression using resampling datasets X1, y1.
print("Baseline model with Logistic regression")
log_regression(X, y)
# Out:
# Baseline model with Logistic regression
#
#
# [Test] Accuracy score (y_predict_test, ytestlr): 0.7934692524448864
#
#
# [Training] Accuracy score: (ylr, y_predict_training) 0.7905425007252683
#               precision    recall  f1-score   support
#
#            0       0.80      0.97      0.88      4512
#            1       0.75      0.27      0.40      1521
#
#     accuracy                           0.79      6033
#    macro avg       0.77      0.62      0.64      6033
# weighted avg       0.79      0.79      0.75      6033

# %%
# Under sampling
lr = LogisticRegression()

def under_sampling(clf, X,y):
    Precisions = []
    Recalls = []
    #define the undersampling method
    undersample = NearMiss(version=1,n_neighbors=3)

    #print('Size of majority dataset:')
    #print(Counter(y))
    
    for i in range(20):
        # transform the dataset
        X1, y1 = undersample.fit_resample(X,y) 

        # summarize the new class distribution
        counter = Counter(y1)
        #print('Size of majority dataset after undersampling:')
        #print(counter)
        
        # Create traiing, test set.
        X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size = 0.2)
        
        # Fit the model
        clf.fit(X_train, y_train)
        
        # Make predict the test set
        y_predict_test = clf.predict(X_test)
        
        # Calculate precision, recall
        Precisions.append(precision_score(y_test, y_predict_test))
        Recalls.append(recall_score(y_test, y_predict_test))
    return Precisions, Recalls


# Fit the Logistic Regression to undersampling datasets 
# and get the Precrisions, and Recalls.
lr_precisions, lr_recalls = under_sampling(lr, X,y)

# Plot the Precisions and Recalls of resampling datasets 
# with Logistic Regression
avg_precision = sum(lr_precisions)/len(lr_precisions)
print('Average Precisions', avg_precision)
plt.plot(lr_precisions)
plt.title('Precisions of resampling datasets ')
plt.show()

avg_recall = sum(lr_recalls)/len(lr_recalls)
print('Average Recalls', avg_recall)
plt.plot(lr_recalls)
plt.title('Recalls of resampling datasets ')
plt.show()
# Out:
# C:\Users\khanh\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\khanh\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# #### Data Exploratory Analysis

# %%
# Get data information
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# salary            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adult.shape
# Out:
# (32561, 15)

# %% [markdown]
# The data set contain 32561 records and 15 features. There are 14 input features and 1 target feature (Salary). The input features contain 9 categorical features, and 5 numberical features

# %%
# Get summary statistics
adult.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# #### Missing data

# %%
missing_df = adult.isnull().sum(axis=0).sort_values(ascending=False).reset_index()
missing_df.columns = ['features','missing counts']
missing_df.shape
missing_df

#fig,ax=plt.subplots(figsize=(12,18))
#sns.barplot(y='features',x='missing counts',data=missing_df)
#plt.show()
# Out:
#           features  missing counts
# 0           salary               0
# 1   native-country               0
# 2   hours-per-week               0
# 3     capital-loss               0
# 4     capital-gain               0
# 5              sex               0
# 6             race               0
# 7     relationship               0
# 8       occupation               0
# 9   marital-status               0
# 10   education-num               0
# 11       education               0
# 12          fnlwgt               0
# 13       workclass               0
# 14             age               0

# %% [markdown]
# There is no missing data in the dataset

# %% [markdown]
# #### Outlier detection

# %%
# Get numerical features
num_features = adult.select_dtypes(include=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']).columns.values.tolist()
num_features
# Out:
# ['age',
#  'fnlwgt',
#  'education-num',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week']

# %%
# Draw boxplots
for col in num_features:
    sns.boxplot(adult[col])
    plt.show()
# Out:
# C:\Users\khanh\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\khanh\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# #### Target value

# %%
# Explore target value
def label_function(val):
    return f'{val / 100 * len(df):.0f}\n{val:.0f}%'

df = adult[['salary','sex']]
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5))

df.groupby('salary').size().plot(kind='pie',autopct=label_function, textprops={'fontsize': 15},
                                  colors=['tomato', 'gold', 'skyblue'], ax=ax1)

df.groupby('sex').size().plot(kind='pie', autopct=label_function, textprops={'fontsize': 15},
                                 colors=['violet', 'lime'], ax=ax2)

ax1.set_ylabel('Per Salary Range', size=22)
ax2.set_ylabel('Per Gender', size=22)
#plt.tight_layout()

plt.title('Salary by Range and by Gender')
plt.show()

# %%
adult.groupby('education').size().plot(kind='bar')
plt.show()

# %%
adult.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
adult.groupby('education')

# %% [markdown]
# #### Correlation Analysis

# %%
sns.pairplot(adult, diag_kind='kde')
plt.show()

# %%
# Check feature correlation with target 'logerror'
corr = adult[num_features].corr()

plt.figure(figsize=(10,10))
sns.heatmap(corr, annot=True)
plt.title('Feature correlation')
plt.show()

# %% [markdown]
# Comments:
# The target value Salary is not highly correlated with other features.
